# %%
# %matplotlib qt
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Given
dir_features = os.path.expanduser('~/research/results/wash-u/features/')

# %% [markdown]
# # Find missing files

# %%
fnames = [f for f in os.listdir(dir_features) if f[-4:] == '.csv']
# fnames

# %%
# len(fnames)

# 208 * 2

# int('7006')

# %%
subj_inds = np.array([int(f[:4]) for f in fnames])
# subj_inds

# %%
plt.figure()
plt.hist(subj_inds, bins=np.arange(subj_inds.min() - 1, subj_inds.max() + 1))
plt.xlim([7360, 7475])
plt.show()
