# %%
# %matplotlib qt
import mne
import numpy as np
import os.path as op
import matplotlib.pyplot as plt

# %%
# Read preprocessed EEG data
data_path = op.expanduser('~/data/wash-u/preprocessed/v2/')
fname_raw = '7005_4_rest1_ec_ica_ssp_eeg.fif'
fpath_raw = op.join(data_path, fname_raw)
raw = mne.io.read_raw_fif(fpath_raw, preload=True)

raw.info
# Out:
# Opening raw data file C:\Users\chholakp2/data/wash-u/preprocessed/v2/7005_4_rest1_ec_ica_ssp_eeg.fif...
# Isotrak not found
#     Read a total of 2 projection items:
#         ECG-eeg--0.200-0.400-PCA-01 (1 x 30) active
#         ECG-eeg--0.200-0.400-PCA-02 (1 x 30) active
#     Range : 0 ... 155879 =      0.000 ...   311.758 secs
# Ready.
# Reading 0 ... 155879  =      0.000 ...   311.758 secs...
# <Info | 11 non-empty values
#  bads: []
#  ch_names: O2, O1, Pz, P4, P8, C4, T8, P7, P3, Cz, C3, Fz, F4, F8, T7, F3, ...
#  chs: 30 EEG, 1 ECG, 1 EOG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 32
#  projs: ECG-eeg--0.200-0.400-PCA-01: on, ECG-eeg--0.200-0.400-PCA-02: on
#  sfreq: 500.0 Hz
#  subject_info: 2 items (dict)
# >

# %%
raw.plot(n_channels=len(raw))
# Out:
# Using qt as 2D backend.
# Channels marked as bad:
# none

# %%
event_dict = {'0': 666, '1': 1, '2': 2, '3': 1, '4': 10}

# %%
events, event_dict = mne.events_from_annotations(raw, event_id=event_dict)
events

# %%
event_dict

# %%
fig = mne.viz.plot_events(events, event_id=event_dict, sfreq=raw.info['sfreq'],
                         first_samp=raw.first_samp)

# %%
print(raw.annotations.description)

# %%
print(raw.annotations.onset)

# %%
t_msg = [76.627998, 153.723999, 231.233994, 308.329987]
np.diff(t_msg)

# %%
raw.crop(tmin=157, tmax=217)
